# %% [markdown]
# <a href="https://colab.research.google.com/github/Song-Hyunsub/Univ_Study/blob/main/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D_%EC%9D%B4%ED%95%B4_%EC%8B%A4%EC%8A%B5/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D_4%EC%B0%A8%EC%8B%9C_%ED%85%8C%EC%8A%A4%ED%8A%B8_%EA%B5%B0%EC%A7%91%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
from copy import deepcopy
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

# %%
data = pd.read_csv('xclara.csv')
print(data.shape)
data.head()
# Out:
# (3000, 2)
#           V1         V2
# 0   2.072345  -3.241693
# 1  17.936710  15.784810
# 2   1.083576   7.319176
# 3  11.120670  14.406780
# 4  23.711550   2.557729

# %%
f1 = data['V1'].values
f2 = data['V2'].values
X = np.array(list(zip(f1, f2)))
plt.scatter(f1, f2, c='black', s=7)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1288: UserWarning: findfont: Font family ['Gulim'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#위의 점들을 보고
#k-means를 이용하여 군집분석을 하여 봅시다. (3개정도면 적당하겠네요) 어떻게 하면 될까요?

# %%
from sklearn.cluster import KMeans

# K-MEANS 군집모델 생성
kmeans = KMeans(n_clusters=3)

# 모델의 훈련
kmeans = kmeans.fit(X)

# 군집의 예측
labels = kmeans.predict(X)

# 군집의 중심좌표
centroids = kmeans.cluster_centers_

# %%
centroids
# Out:
# array([[ 40.68362784,  59.71589274],
#        [ 69.92418447, -10.11964119],
#        [  9.4780459 ,  10.686052  ]])

# %%
labels
# Out:
# array([2, 2, 2, ..., 1, 1, 1])

# %%
#군집마다 색깔을 입혀봅시다.
colors = ['r', 'g', 'b']
fig, ax = plt.subplots()

for i in range(3):
        points = np.array([X[j] for j in range(len(X)) if labels[j] == i])
        ax.scatter(points[:, 0], points[:, 1], s=7, c=colors[i])
